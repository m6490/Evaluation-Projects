# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# ## Attribute Information

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# ## Attribute Information
# 1.	W(Output) - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# ## Requirement:
# Finding Number of predicted wins (W) using Machine Learning Model. We will be using Regression model as the output to be predicted is continuous.

# %%
# importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the dataset
df_baseball=pd.read_csv("baseball.csv")
df_baseball.head()

# %% [markdown]
# ## Starting the EDA

# %%
# Checking Configuration of Dataset
df_baseball.shape
# Out:
# (30, 17)

# %% [markdown]
# Obs- There are total 17 columns of which 16 are input features and 1 is output column and consist of information of 30 teams

# %%
# Checking data types of attributes
df_baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# Obs- All the data columns have continuous data

# %%
# Checking for null values if any
df_baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Obs- There is no null data present in the dataset

# %%
# Checking for white spaces
df_baseball.loc[0:]==" "
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %% [markdown]
# Obs- There are no white spaces in the data

# %%
#Check for duplicate data
df_baseball.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Obs- There is no duplicate data in the dataset

# %%
#Checking description of dataset
df_baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# Visualizing the statistics of the columns using heatmap.
plt.figure(figsize=(15,7))
sns.heatmap(df_baseball.describe(),linewidths = 0.1,fmt='0.2f',annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Obs-
# * We can see the mean in all columns is either  very slightly greater than or leasser than median, thus we can say a left and right skewness is present in almost all columns.
# * The max of target column "W" is exceptionally high than 75th percentile that means outliers are present in target column.
# * Similarly the max in columns 'R','HR','SO','SB',ERA','CG',SHO','SV','E' is exceptionally high than 75th percentile, thus we can say outliers are present in those columns too

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### 1. Univariate Analysis

# %%
# Histogram plot to check distribution of attributes

# %%
sns.histplot(df_baseball['W'],bins=10)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# Obs- We can see the maximum number of Wins with the most count of 100 is credited to 3 pitchers, while the range 90-95 to 2 pitchers, 80 to 5 itchers and so on.

# %%
sns.histplot(df_baseball['R'],bins=10,color='g')
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %% [markdown]
# Obs- We can see most of the teams have managed to score Runsin range 650-700, a few above 750-800 and only a single teams who has scored above 850 runs and also there is only single team that has scored below 600

# %%
sns.histplot(df_baseball['RA'],bins=10,color='m')
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %% [markdown]
# Obs- The Run Average of almost half of the teams is 600-650, while of other half of the teams is 700-750, a few those have managed to make run average above 800 and a single team that has run average below 550

# %%
sns.histplot(df_baseball['SHO'],bins=10,color='y')
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %% [markdown]
# Obs- There are 7 teams who have pitchers that have offered 12 games of shutout, 5 teams who have pitchers that have offered 10 games of shutout, 4 teams that have pitchers that have offered either 8-9 or 13-14 games od shutout

# %%
# Distribution plot to check skewness in the features

# %%
plt.figure(figsize=(35,35))
plotnumber=1

for column in df_baseball:
    if plotnumber<=17: #as there are 17 columns 
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df_baseball[column])
        plt.xlabel(column,fontsize=25)
    plotnumber +=1
plt.show()

# %% [markdown]
# Obs-
# * We can see Right Skewness is present in columns: 'AB','H' ,'3B','HR','CG','SV','E'
# * We can see Left Skewness is present in columns: 'W','R','2B','BB','SO','RA','ER','ERA','SHO'
# * The column 'SB' has normal distribution

# %%
#box plot to check outliers

# %%
df_baseball.plot(kind='box',subplots=True,layout=(5,4),figsize=(30,30))
# Out:
# W         AxesSubplot(0.125,0.749828;0.168478x0.130172)
# R      AxesSubplot(0.327174,0.749828;0.168478x0.130172)
# AB     AxesSubplot(0.529348,0.749828;0.168478x0.130172)
# H      AxesSubplot(0.731522,0.749828;0.168478x0.130172)
# 2B        AxesSubplot(0.125,0.593621;0.168478x0.130172)
# 3B     AxesSubplot(0.327174,0.593621;0.168478x0.130172)
# HR     AxesSubplot(0.529348,0.593621;0.168478x0.130172)
# BB     AxesSubplot(0.731522,0.593621;0.168478x0.130172)
# SO        AxesSubplot(0.125,0.437414;0.168478x0.130172)
# SB     AxesSubplot(0.327174,0.437414;0.168478x0.130172)
# RA     AxesSubplot(0.529348,0.437414;0.168478x0.130172)
# ER     AxesSubplot(0.731522,0.437414;0.168478x0.130172)
# ERA       AxesSubplot(0.125,0.281207;0.168478x0.130172)
# CG     AxesSubplot(0.327174,0.281207;0.168478x0.130172)
# SHO    AxesSubplot(0.529348,0.281207;0.168478x0.130172)
# SV     AxesSubplot(0.731522,0.281207;0.168478x0.130172)
# E            AxesSubplot(0.125,0.125;0.168478x0.130172)
# ...

# %% [markdown]
# Obs- We can observe that there are outliers present in  columns 'R','ERA','SHO','SV','E', we will be treating them later

# %% [markdown]
# ### Bivariate Analysis

# %%
# Checking relationship between Runs Scored(R) and No. of Wins(W)
sns.lineplot(x='R',y='W', data=df_baseball)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# Obs- We can see the number of wins is high when higher runs are scored.

# %%
# Checking relationship between At Bat(AB) and No. of Hits(H)
sns.lineplot(x='AB',y='H', data=df_baseball)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='H'>

# %% [markdown]
# Obs- We can see whenever the batting position is At bat(AB), max Hits are earned.

# %%
# Checking relationship between Complete Game(CG) and No. of Wins(W)
sns.lineplot(x='CG',y='W', data=df_baseball)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %% [markdown]
# Obs- We can observe whenever there is a single pitcher pitching a complete game (CG), the number of wins is always above 80(as a complete game itself indicates the win is in favour of the pitcher)

# %%
# Checking relationship between Shutout(SHO) and No. of Wins(W)
sns.regplot(x='SHO',y='W', data=df_baseball)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %% [markdown]
# Obs- We can observe a positive relationsip between Shutout(SHO) [where the pitcher does not allow the opposing team to score a run] and wins he earns for the team.

# %%
# Checking relationship between Shutout(SHO) and Run Average(RA)
sns.regplot(x='SHO',y='RA', data=df_baseball)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='RA'>

# %% [markdown]
# Obs- We can see that the Run Average decreases whenever there is SHO(simply because the pitcher doesnot allow to make runs)

# %%
# Checking relationship between Earned Runs (ER) and Earned Runs Average(ERA)
sns.lineplot(x='ER',y='RA', data=df_baseball)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='RA'>

# %% [markdown]
# Obs- For good Earned Runs, the Run Average will follow

# %%
# Checking relationship between Save (SV) and Wins(W)
sns.regplot(x='SV',y='W',data=df_baseball)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# Obs- When a pitcher succeeds in saving the game, the number of wins credited are increse mostly.

# %%
# Checking relationship between Runs Average (RA) and Wins(W)
sns.lineplot(x='RA',y='W',data=df_baseball)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %% [markdown]
# Obs- We can see even if Run Average is high, still the wins are decresing, the reason is because of pitchers contributing towards CG(Complete Game) and SHO(Shutout)

# %% [markdown]
# ## Checking Correlation

# %%
df_baseball.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# Correlation using heatmap
plt.figure(figsize=(15,15))
sns.heatmap(df_baseball.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Obs- We can see,
#
# * highly positive correlated columns(>7):('AB and H'),('RA and ER'),('RA and ERA'),('ER and ERA')
# * positive correlated columns(>4):('W and R'),('W and BB'),('W and SHO'),('W and SV'),('R and H'),('R and 2B'),('R and HR'),('AB and 2B and 3B'),('H and 2B and 3B')('BB and CG'),('BB and SHO')
# * highly negative correlated columns(>-6):('W and RA'),('W and ER'),('W and ERA'),('RA and SHO'),('RA and SV'),('ER and SHO'),('ER and SV'),('ERA and SHO'),('ERA and SV')
# * negative correlated columns(>-4):('H and SO'),('3B and HR'),('3B and BB'),('BB and RA'),('BB and ER'),('3B and ERA')
#
#
# #### * We can also predict that multi-collinearity is present between ('RA','ER' and 'ERA'),('RA',SHO'),('RA','SV'),('ER','SHO')('SV','ERA') and thus would be checking it through VIF and removing it later.

# %%
# A quick view of Correlation between Features and Target using Heatmap

plt.figure(figsize=(22,7))
df_baseball.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='r')
plt.xlabel('Features',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title('Correlation between label and features using Bar plot',fontsize=18)
plt.show()

# %% [markdown]
# Obs-
# * Positively Correlated Colums:
# SV(Saves)
# BB(Walks)
# SHO(Shoutouts)
# R(Runs)
# 2B(Doubles)
# HR(Homeruns)
# SO(Strikeouts)
# CG(Complete Games)
# H(Hits)
# * Negatively Correlated Columns :
# ERA(Earned Run Average)
# RA(Runs allowed)
# ER(Earned Runs)
# 3B(Triples)
# SB(Stolen bases)
# E(Error)
# AB(At Bats)

# %% [markdown]
# ## Deleting Unwanted Columns

# %% [markdown]
# Obs- We have observed the columns 'H','CG','AB','E' have almost zero co-relation with the target column, For now deleting the Hits('H')column as it has no contribution towards wins

# %%
df_baseball.drop('H',inplace=True,axis=1)
df_baseball.head()
# Out:
#     W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  95  724  5575  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  83  696  5467  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  81  669  5439  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  76  622  5533  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  74  689  5605  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %% [markdown]
# Obs- The Hit('H') column is deleted

# %% [markdown]
# ## Detecting Outliers and Treating them

# %%
#Method 1: Z-Score
from scipy.stats import zscore
z=np.abs(zscore(df_baseball))
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %% [markdown]
# Obs- We already saw outliers were present through box plot, zscore has shown the exact loaction where outliers are present

# %%
df_baseball_new=df_baseball[(z<3).all(axis=1)]

# %%
print("df_baseball.shape:",df_baseball.shape, "\ndf_baseball_new.shape:",df_baseball_new.shape)
# Out:
# df_baseball.shape: (30, 16)
# df_baseball_new.shape: (29, 16)

# %%
# Checking data loss
data_loss=(30-29)/30*100
data_loss
# Out:
# 3.3333333333333335

# %%
# Method 2: IQR(Inter Quartile) Method
Q1=df_baseball.quantile(0.25)
Q3=df_baseball.quantile(0.75)
IQR=Q3 - Q1

df_baseball_new2=df_baseball[~((df_baseball < (Q1 - 1.5 * IQR)) |(df_baseball > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print("df_baseball.shape:",df_baseball.shape, "\ndf_baseball_new2.shape:",df_baseball_new2.shape)
# Out:
# df_baseball.shape: (30, 16)
# df_baseball_new2.shape: (20, 16)

# %%
# Checking data loss
data_loss=(30-20)/30*100
data_loss
# Out:
# 33.33333333333333

# %% [markdown]
# Obs- The Data Loss in IQR method is very high, so we will be going with Z-score method

# %%
# Reassigning obtained value to original dataframe
df_baseball=df_baseball_new
df_baseball.shape
# Out:
# (29, 16)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Seperating Input and Target variables

# %%
x=df_baseball.drop(columns='W')
y=df_baseball['W']

# %%
x.shape
# Out:
# (29, 15)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# ## Data Transformation to treat Skewness

# %% [markdown]
# ### Checking Skewness

# %%
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# obs- keeping the acceptable range +/- 0.5, we can see skewness is present in columns 'CG', 'SHO','SV','E'.
# * Applying transformation method to treat the skewness

# %% [markdown]
# ### Applying Transformation Method

# %%
x=pd.DataFrame(x)
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer() 
skew_col = ["CG","SHO","SV","E"]
x[skew_col]= pt.fit_transform(x[skew_col].values)

# %%
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# Obs- We can see the Skewness has gone from all those columns that contained it

# %% [markdown]
# ### Data Scaling

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x_scale=st.fit_transform(x)
x_scale=pd.DataFrame(x_scale)

# %%
x=pd.DataFrame(data=x_scale)

# %% [markdown]
# ## Checking Multi-Collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif['Features']=x.columns
    print(vif)

vif_cal()
# Out:
#      VIF Factor  Features
# 0      6.228510         0
# 1     11.156523         1
# 2      3.522497         2
# 3      3.210581         3
# 4      7.373076         4
# 5      3.230566         5
# 6      2.798374         6
# 7      1.774505         7
# 8    196.171346         8
# 9   1920.321732         9
# 10  1378.434516        10
# 11     2.580312        11
# 12     3.166773        12
# 13     5.082916        13
# 14     1.785718        14

# %% [markdown]
# * (Feature Denoted as: 0:R, 1:AB, 2:2B, 3:3B, 4:HR, 5:BB, 6:SO, 7:SB, 8:RA, 9:ER, 10:ERA, 11:CG, 12:SHO, 13:SV, 14:E)
#
# * Keeping the acceptable range as below or equal 10, we observe the VIF of  AB, RA,ER [They had correllation of 0.99]and ERA is high
# * Deleting the column 'ER' as it has max VIF
# * Also deleting the column 'AB' as it has VIF>10 and also has almost 0 correlation with target column

# %%
x.drop(9, axis =1, inplace=True) # Dropping 'ER' column

# %%
x.shape
# Out:
# (29, 14)

# %%
x.drop(1, axis =1, inplace=True) # Dropping 'AB' column

# %%
x.shape
# Out:
# (29, 13)

# %%
# Rechecking the VIF
vif_cal()
# Out:
#     VIF Factor  Features
# 0     4.077665         0
# 1     2.903294         2
# 2     3.071921         3
# 3     5.035984         4
# 4     3.071078         5
# 5     2.492130         6
# 6     1.477468         7
# 7    92.289176         8
# 8    94.438234        10
# 9     2.272921        11
# 10    2.772807        12
# 11    2.442383        13
# 12    1.780088        14

# %% [markdown]
# Obs- The VIF of 8:RA ,10: ERA is again high, we will be dropping 'RA' column because, even if its VIF is slight less than 'ERA', 'ERA' has slight more correlation with target column

# %%
x.drop(8, axis =1, inplace=True) # Dropping 'RA' column

# %%
x.shape
# Out:
# (29, 12)

# %% [markdown]
# ## Data Modelling

# %% [markdown]
# ### Finding Best Random State

# %%
#importing necessary libraries
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score

from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state =i)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9889777951970599  on Random_state  47

# %% [markdown]
# ### Splitting data into Train-Test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=47)

# %%
x_train.shape
# Out:
# (23, 12)

# %%
y_train.shape
# Out:
# (23,)

# %%
x_test.shape
# Out:
# (6, 12)

# %%
y_test.shape
# Out:
# (6,)

# %% [markdown]
# ### Using various Machine Learning Algorithms

# %% [markdown]
# #### 1. Linear Regression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.9272135934491457

# %%
predlr=lr.predict(x_test)
print("The performance metrix of Linear Regression is as below \n")
print("r2_score=",r2_score(y_test,predlr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predlr))
print("Mean Squared Error:",mean_squared_error(y_test,predlr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# The performance metrix of Linear Regression is as below
#
# r2_score= 0.9889777951970599
#
# Mean Absolute Error: 1.050780055883519
# Mean Squared Error: 1.3912471840155574
# Root Meand Squared Error: 1.1795114175011436

# %% [markdown]
# #### 2. Support Vector Regressor

# %%
svr=SVR()
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
# Out:
# 0.21853248131367076

# %%
predsvr=svr.predict(x_test)
print("The performance metrix of Support Vector Regressor is as below \n")
print("r2_score=",r2_score(y_test,predsvr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predsvr))
print("Mean Squared Error:",mean_squared_error(y_test,predsvr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predsvr)))
# Out:
# The performance metrix of Support Vector Regressor is as below
#
# r2_score= 0.09879175479438818
#
# Mean Absolute Error: 8.94815207271158
# Mean Squared Error: 113.75250739484169
# Root Meand Squared Error: 10.665482051686256

# %% [markdown]
# #### 3. Decision Tree Regressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
preddtr=dtr.predict(x_test)
print("The performance metrix of Decision Tree Regressor is as below \n")
print("r2_score=",r2_score(y_test,preddtr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,preddtr))
print("Mean Squared Error:",mean_squared_error(y_test,preddtr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,preddtr)))
# Out:
# The performance metrix of Decision Tree Regressor is as below
#
# r2_score= 0.8362676056338028
#
# Mean Absolute Error: 4.333333333333333
# Mean Squared Error: 20.666666666666668
# Root Meand Squared Error: 4.546060565661952

# %% [markdown]
# #### 4. K Neighbors Regressor

# %%
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
# Out:
# 0.6473842825129432

# %%
predknr=knr.predict(x_test)
print("The performance metrix of K Neighbors Regressor is as below \n")
print("r2_score=",r2_score(y_test,predknr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predknr))
print("Mean Squared Error:",mean_squared_error(y_test,predknr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predknr)))
# Out:
# The performance metrix of K Neighbors Regressor is as below
#
# r2_score= 0.47690140845070417
#
# Mean Absolute Error: 6.333333333333333
# Mean Squared Error: 66.02666666666669
# Root Meand Squared Error: 8.125679458769383

# %% [markdown]
# #### 5.Random Forest Regressor

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
# Out:
# 0.9321627965381346

# %%
predrfr=rfr.predict(x_test)
print("The performance metrix of Random Forest Regressor is as below \n")
print("r2_score=",r2_score(y_test,predrfr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predrfr))
print("Mean Squared Error:",mean_squared_error(y_test,predrfr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predrfr)))
# Out:
# The performance metrix of Random Forest Regressor is as below
#
# r2_score= 0.6789351672535209
#
# Mean Absolute Error: 5.728333333333336
# Mean Squared Error: 40.52551666666671
# Root Meand Squared Error: 6.365965493675465

# %% [markdown]
# #### 6.Ada Boost Regressor

# %%
adr=AdaBoostRegressor()
adr.fit(x_train,y_train)
adr.score(x_train,y_train)
# Out:
# 0.9865658537811459

# %%
predadr=adr.predict(x_test)
print("The performance metrix of Ada Boost Regressor is as below \n")
print("r2_score=",r2_score(y_test,predadr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predadr))
print("Mean Squared Error:",mean_squared_error(y_test,predadr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predadr)))
# Out:
# The performance metrix of Ada Boost Regressor is as below
#
# r2_score= 0.7044762323943663
#
# Mean Absolute Error: 5.683333333333333
# Mean Squared Error: 37.301666666666655
# Root Meand Squared Error: 6.107509039425701

# %% [markdown]
# #### 7.Gradient Boosting Regressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
# Out:
# 0.9999998931006465

# %%
predgbr=gbr.predict(x_test)
print("The performance metrix of Gradient Boosting Regressor is as below \n")
print("r2_score=",r2_score(y_test,predgbr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predgbr))
print("Mean Squared Error:",mean_squared_error(y_test,predgbr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predgbr)))
# Out:
# The performance metrix of Gradient Boosting Regressor is as below
#
# r2_score= 0.7476262028027076
#
# Mean Absolute Error: 4.709139092807054
# Mean Squared Error: 31.855181512902675
# Root Meand Squared Error: 5.644039467695338

# %% [markdown]
# ### Regularization to overcome Over-Fitting (Lasso,Ridge)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# #### 8. Lasso Regression

# %%
ls=Lasso(alpha=0.1)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9214084125954449

# %%
predls=ls.predict(x_test)
print("The performance metrix of Lasso Regressor is as below \n")
print("r2_score=",r2_score(y_test,predls),"\n")
print("Mean Absolute Error:",mean_absolute_error(y_test,predls))
print("Mean Squared Error:",mean_squared_error(y_test,predls))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predls)))
# Out:
# The performance metrix of Lasso Regressor is as below
#
# r2_score= 0.9574866838935472
#
# Mean Absolute Error: 2.099673778196783
# Mean Squared Error: 5.366125232992264
# Root Meand Squared Error: 2.316489851692052

# %% [markdown]
# #### 9. Ridge Regression

# %%
rg=Ridge(alpha=0.1)
rg.fit(x_train,y_train)
rg.score(x_train,y_train)
# Out:
# 0.9270353943267392

# %%
predrg=rg.predict(x_test)
print("The performance metrix of Ridge Regressor is as below \n")
print("r2_score=",r2_score(y_test,predrg),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predrg))
print("Mean Squared Error:",mean_squared_error(y_test,predrg))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predrg)))
# Out:
# The performance metrix of Ridge Regressor is as below
#
# r2_score= 0.9871991357601062
#
# Mean Absolute Error: 0.8251882305185028
# Mean Squared Error: 1.6157535307243667
# Root Meand Squared Error: 1.2711229408378903

# %% [markdown]
# ### Cross Validation

# %%
# Using of K-Fold cross-validation technique

predlrr= lr.predict(x_test)

from sklearn.model_selection import cross_val_score

test_accuracy= r2_score(y_test,predlr)

for j in range(2,6):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean= cv_score.mean()
    print('At cv:',j)
    print('Cross_Validation_score is:',cv_mean*100)
    print('Accuracy is :',test_accuracy*100)
    print("\n")
# Out:
# At cv: 2
# Cross_Validation_score is: 17.928836786149283
# Accuracy is : 98.89777951970599
#
#
# At cv: 3
# Cross_Validation_score is: 45.245872727734906
# Accuracy is : 98.89777951970599
#
#
# At cv: 4
# Cross_Validation_score is: 50.020867070052944
# Accuracy is : 98.89777951970599
#
#
# At cv: 5
# Cross_Validation_score is: 46.39621897765697
# Accuracy is : 98.89777951970599

# %% [markdown]
# Obs- Selecting the fold value as 4

# %%
# cv score for Linear Regression 
cvlr=cross_val_score(lr,x,y,cv=4).mean()
print('CV score  for Linear rgerssion:',cvlr)
print("And Difference between CV and r2_score =", r2_score(y_test,predlr)-cvlr)
# Out:
# CV score  for Linear rgerssion: 0.5002086707005294
# And Difference between CV and r2_score = 0.4887691244965304

# %%
# cv score for Support Vector Regressor
cvsvr=cross_val_score(svr,x,y,cv=4).mean()
print('CV score  for Support Vector Regressor:',cvsvr)
print("And Difference between CV and r2_score =", r2_score(y_test,predsvr)-cvsvr)
# Out:
# CV score  for Support Vector Regressor: -0.09051016650226679
# And Difference between CV and r2_score = 0.18930192129665496

# %%
# cv score for Decision Tree Regressor
cvdtr=cross_val_score(dtr,x,y,cv=4).mean()
print('CV score  for Decision Tree Regressor:',cvdtr)
print("And Difference between CV and r2_score =", r2_score(y_test,preddtr)-cvdtr)
# Out:
# CV score  for Decision Tree Regressor: -0.2722983283316452
# And Difference between CV and r2_score = 1.108565933965448

# %%
# cv score for K Neighbors Regressor
cvknr=cross_val_score(knr,x,y,cv=4).mean()
print('CV score  for K Neighbors Regressor:',cvknr)
print("And Difference between CV and r2_score =", r2_score(y_test,predknr)-cvknr)
# Out:
# CV score  for K Neighbors Regressor: 0.3396995332812982
# And Difference between CV and r2_score = 0.13720187516940596

# %%
# cv score for Random Forest Regressor
cvrfr=cross_val_score(rfr,x,y,cv=4).mean()
print('CV score  for Random Forest Regressor:',cvrfr)
print("And Difference between CV and r2_score =", r2_score(y_test,predrfr)-cvrfr)
# Out:
# CV score  for Random Forest Regressor: 0.5434878681793396
# And Difference between CV and r2_score = 0.1354472990741813

# %%
# cv score for Ada Boost Regressor
cvadr=cross_val_score(adr,x,y,cv=4).mean()
print('CV score  for Ada Boost Regressor:',cvadr)
print("And Difference between CV and r2_score =", r2_score(y_test,predadr)-cvadr)
# Out:
# CV score  for Ada Boost Regressor: 0.5538847575653381
# And Difference between CV and r2_score = 0.15059147482902824

# %%
# cv score for Gradient Boosting Regressor
cvgbr=cross_val_score(gbr,x,y,cv=4).mean()
print('CV score  for Gradient Boosting Regressor:',cvgbr)
print("And Difference between CV and r2_score =", r2_score(y_test,predgbr)-cvgbr)
# Out:
# CV score  for Gradient Boosting Regressor: 0.2931552657574673
# And Difference between CV and r2_score = 0.45447093704524033

# %%
# cv score for Lasso Regressor
cvls=cross_val_score(ls,x,y,cv=4).mean()
print('CV score  for Lasso Regressor:',cvls)
print("And Difference between CV and r2_score =", r2_score(y_test,predls)-cvls)
# Out:
# CV score  for Lasso Regressor: 0.641170987967339
# And Difference between CV and r2_score = 0.31631569592620823

# %%
# cv score for Ridge Regressor
cvrg=cross_val_score(rg,x,y,cv=4).mean()
print('CV score  for Ridge Regressor:',cvrg)
print("And Difference between CV and r2_score =", r2_score(y_test,predrg)-cvrg)
# Out:
# CV score  for Ridge Regressor: 0.5274165641775999
# And Difference between CV and r2_score = 0.45978257158250635

# %% [markdown]
# Obs-
# * We can observe the difference between CV score and r2_score is least in the models KNR(0.13),RFR(0.13),ADR(0.15)
# * Also considering the r2_score of all 3 models, we will select ADR i.e Ada Boost Regressor as our best model[ As its r2_score (0.70) is considerably high than KNR(0.47)and RFR(0.67)] and find best parameters of it further.

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
adr.get_params()
# Out:
# {'base_estimator': None,
#  'learning_rate': 1.0,
#  'loss': 'linear',
#  'n_estimators': 50,
#  'random_state': None}

# %%
#Selecting few parameter list to pass in Ada Boost Regressor
from sklearn.model_selection import GridSearchCV
# defining parameter range
parameter = {'learning_rate': [0.1, 1, 10, 100],
             'n_estimators': [25,50,75,100, 150],
             'loss':['linear','square','exponential'],
              'random_state':[0,15,42,55,73]}

# %%
# Start Tuning 
adr1=AdaBoostRegressor()
GCV = GridSearchCV(adr1,parameter,cv=4)

GCV.fit(x_train,y_train)  
print(GCV.best_params_)         #printing the best parameter found by Gridsearchcv
# Out:
# {'learning_rate': 1, 'loss': 'square', 'n_estimators': 25, 'random_state': 42}

# %%
#Applying best parameter values on Ada Boost Regressor Algorithm 
baseballbest=AdaBoostRegressor(learning_rate=1, loss='square', n_estimators=25, random_state=42)
baseballbest.fit(x_train,y_train)
baseballbest.score(x_train,y_train)
# Out:
# 0.9819406880800899

# %%
predadr1=baseballbest.predict(x_test)
print("r2_score=",r2_score(y_test,predadr1),"\n")

print("Mean Absolute Error:",mean_absolute_error(y_test,predadr1))
print("Mean Squared Error:",mean_squared_error(y_test,predadr1))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y_test,predadr1)))
# Out:
# r2_score= 0.7949644219483569
#
# Mean Absolute Error: 4.397222222222221
# Mean Squared Error: 25.880046296296282
# Root Meand Squared Error: 5.087243487026769

# %% [markdown]
# Obs- Our best model has given r2_score= 0.7949644219483569 and Mean Absolute Error= 4.397222222222221

# %% [markdown]
# ## Saving the best model

# %%
import joblib

joblib.dump(baseballbest,'baseball.obj')
# Out:
# ['baseball.obj']

# %%
baseball_model=joblib.load('baseball.obj')

# %%
# Viewing Attributes of the best model
baseball_model
# Out:
# AdaBoostRegressor(learning_rate=1, loss='square', n_estimators=25,
#                   random_state=42)

# %% [markdown]
# ## Prediction

# %%
ori = np.array(y_test)
predicted = np.array(baseball_model.predict(x_test))
df_new = pd.DataFrame({"Original":ori,"Predicted":predicted},index= range(len(ori)))
df_new
# Out:
#    Original  Predicted
# 0       100  96.750000
# 1        76  68.500000
# 2        74  74.000000
# 3        86  81.500000
# 4        76  83.333333
# 5        64  67.800000

# %% [markdown]
# Obs- We can see our best model has yielded fairly same results(if not exact)

# %%
# Viewing the difference of prediction using Visualization 
plt.figure(figsize=(12,7))
sns.kdeplot(data=df_new, palette='gist_rainbow_r',gridsize=900, shade=True)
plt.title('Original vs predicted  graph')
# Out:
# Text(0.5, 1.0, 'Original vs predicted  graph')

# %% [markdown]
# ## Concluding Remarks

# %% [markdown]
# * We predicted the outcomes of matches by collecting the match data of 30 teams of the 2014 season using different Regression Models.
# * The prediction accuracies of these models were then checked.
# * Also cross-validation was performed to avoid overfitting of models.
# * The prediction results indicated that Ada Boost Regressor model achieved higher prediction accuracy.
